# %%
import pandas as pd

dataset = pd.read_csv('../Datasets/porto_caracteristicas_terminais.csv', encoding='latin1')

dataset
# Out:
#                                     Porto  Quantidade de Postos de acostagem  \
# 0            TERMINAL DE GRANÉIS LÍQUIDOS                                  6
# 1                   TERMINAL PETROQUÍMICO                                  2
# 2          TERMINAL MULTIPURPOSE DE SINES                                  4
# 3                 TERMINAL DE GÁS NATURAL                                  1
# 4  TERMINAL DE CONTENTORES DE SINES (XXI)                                  1
#
#    Altura do Fundo(m/ZH)   Limite dwt de navios (dwt)  \
# 0                   -28.0                       350.0
# 1                   -12.0                         NaN
# 2                   -18.0                       190.0
# 3                   -15.0                         NaN
# 4                   -17.5                         NaN
#
#     Comprimento do Cais (m)                                Principais produtos
# 0                       NaN     Ramas, Refinados, LPG, Metanol e Nafta Química
# ...

# %%
#drop columns with missing values
dataset = dataset.dropna(axis=1)

# %%
dataset
# Out:
#                                     Porto  Quantidade de Postos de acostagem  \
# 0            TERMINAL DE GRANÉIS LÍQUIDOS                                  6
# 1                   TERMINAL PETROQUÍMICO                                  2
# 2          TERMINAL MULTIPURPOSE DE SINES                                  4
# 3                 TERMINAL DE GÁS NATURAL                                  1
# 4  TERMINAL DE CONTENTORES DE SINES (XXI)                                  1
#
#    Altura do Fundo(m/ZH)                                 Principais produtos
# 0                   -28.0     Ramas, Refinados, LPG, Metanol e Nafta Química
# 1                   -12.0  Propileno, Etileno, Butadieno, ETBE, Etanol, M...
# 2                   -18.0               Granéis Sólidos, Carga Geral e Ro-Ro
# 3                   -15.0                             Gás Natural Liquefeito
# 4                   -17.5                           Navios porta-contentores
