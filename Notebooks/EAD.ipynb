# %%
import pandas as pd

dataset = pd.read_csv('../Datasets/SINES.csv')

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(dataset, title="Pandas Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-05 18:17:28.685816&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Dock Timestamp               4000 non-null   object
#  1   Undock Timestamp             3987 non-null   object
#  2   Vessel Name                  4000 non-null   object
#  3   Berth Name                   4000 non-null   object
#  4   Terminal Name                4000 non-null   object
#  5   Current Port                 4000 non-null   object
#  6   Current Port Ata             3999 non-null   object
#  7   Destination Port             2955 non-null   object
#  8   Load Condition At Arrival    871 non-null    object
#  9   Current Port Atd             3936 non-null   object
#  10  Load Condition At Departure  857 non-null    object
#  11  Time At Berth                3987 non-null   float64
#  12  Time At Port                 3935 non-null   float64
# ...
